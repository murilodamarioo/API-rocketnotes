# %% [markdown]
# <a href="https://colab.research.google.com/github/murilodamarioo/API-rocketnotes/blob/main/statistics_for_devs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Dicionário de faturamento
dict_invoicing = {
    'ref_date': [
        '2023-01-01',
        '2020-02-01',
        '2021-03-01',
        '2022-04-01',
        '2023-05-01',
        '2023-06-01',
        '2020-07-01',
        '2021-08-01',
        '2022-09-01',
        '2023-10-01',
        '2022-11-01',
        '2023-12-01',
        ],
    'value': [
        400000,
        890000,
        760000,
        430000,
        920000,
        340000,
        800000,
        500000,
        200000,
        900000,
        570000,
        995000,
        ]
}

# %%
df_invoicing = pd.DataFrame(dict_invoicing)

# %%
df_invoicing
# Out:
#       ref_date   value
# 0   2023-01-01  400000
# 1   2020-02-01  890000
# 2   2021-03-01  760000
# 3   2022-04-01  430000
# 4   2023-05-01  920000
# 5   2023-06-01  340000
# 6   2020-07-01  800000
# 7   2021-08-01  500000
# 8   2022-09-01  200000
# 9   2023-10-01  900000
# 10  2022-11-01  570000
# 11  2023-12-01  995000

# %%
# Here we calculate the sales average
sales_average = round(df_invoicing['value'].mean(), 2)

# %%
sales_average
# Out:
# 642083.33

# %%
# vertical bar chart showing reference month and value
df_invoicing.plot.bar(x='ref_date', y='value')
# Out:
# <Axes: xlabel='ref_date'>

# %%
df_invoicing.plot.line(x='ref_date', y='value')
# Out:
# <Axes: xlabel='ref_date'>
